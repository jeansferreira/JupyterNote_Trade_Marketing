# %% [markdown]
# # Machine Learning em Python
#
# Ao investir em sistemas que coletam e analisam estas informações, é possível automatizar as pesquisas de marketing, com análises preditivas, mineração de dados e o rastreamento de palavras-chave. Dessa forma, os profissionais de marketing conseguem definir o comportamento do internauta, da concorrência e do mercado e, assim, implementar estratégias – de mídia, conteúdo, promocionais – mais certeiras.
#
# Com Big Data, o que muda nos departamentos de marketing é a possibilidade de prever comportamentos de compra com mais precisão por meio da coleta de dados a partir de um grande número de fontes, principalmente as redes sociais e os canais digitais.

# %%
import pandas as pd
import numpy as np
import itertools
import matplotlib as plt
# %matplotlib inline

# %%
df = pd.read_csv("clientes.csv", delimiter=";");df.head(30)
# Out:
#     cliente perfil  valor_total_ticket  idade  renda_sm  recorrencia
# 0         1      b                5952     24       3.9           50
# 1         2      c                7676     34       7.5           52
# 2         3      b                5809     24       3.0           45
# 3         4      b                7004     31       4.2           38
# 4         5      c                6271     25       4.8           53
# 5         6      b                5149     22       5.1           38
# 6         7      b                4967     23       3.6           41
# 7         8      c                7192     28       4.8           63
# 8         9      b                6261     28       5.1           40
# 9        10      b                6437     33       3.0           43
# 10       11      c                6541     28       6.3           60
# 11       12      b                6598     24       3.6           37
# 12       13      a                5547     35       0.9           17
# ...

# %% [markdown]
# Remove a coluna Cliente para manipulação dos dados nos algoritmos de classificação

# %%
df = df.drop('cliente', 1)

# %% [markdown]
# Separa os primeiros 500 usuários

# %%
df_humans = df[:500]

# %%
df_humans.shape
# Out:
# (500, 5)

# %% [markdown]
# ## Realiza a classificação em vários algoritmos para descobir aquele com melhor desempenho

# %% [markdown]
# # Arvore de decisão na classificação Manual

# %%
from pandas import read_csv
from sklearn import model_selection
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix

# Carregar os dados:
array = df_humans.values

# Separar array em componentes de input e output:
x = array[:,1:5]
y = array[:,0]

# Definir tamanho das amostras:
teste_size = 0.3

# Garantir que os resultados podem ser reproduzidos no estado randômico:
seed = 7

# Criando os conjuntos de dados de treino e de teste
x_treino, x_teste, y_treino, y_teste = model_selection.train_test_split(x, y, test_size = teste_size, random_state = seed)

# Criação do modelo
modelo = DecisionTreeClassifier()
modelo.fit(x_treino, y_treino)

# matriz de confusão:
pred_tree = modelo.predict(x_teste)
mat = confusion_matrix(y_teste, pred_tree)
print("Matriz de confusão: \n"+str(mat))

#acurácia:
acuracia = modelo.score(x_teste, y_teste)
print("\nAcurácia: "+str(acuracia*100)+"%")
# Out:
# Matriz de confusão:
# [[13  0  0]
#  [ 0 55  3]
#  [ 0  1 78]]
#
# Acurácia: 97.33333333333334%

# %% [markdown]
# # Regressão Logistica na classificação Manual

# %%
# Import dos módulos
from pandas import read_csv
from sklearn import model_selection
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix

# Carregar os dados:
array = df_humans.values

# Separar array em componentes de input e output:
x = array[:,1:5]
y = array[:,0]

# Definir tamanho das amostras:
teste_size = 0.3

# Garantir que os resultados podem ser reproduzidos no estado randômico:
seed = 7

# Criando os conjuntos de dados de treino e de teste
x_treino, x_teste, y_treino, y_teste = model_selection.train_test_split(x, y, test_size = teste_size, random_state = seed)

# Criação do modelo
modelo = LogisticRegression()
modelo.fit(x_treino, y_treino)

# matriz de confusão:
pred_lr = modelo.predict(x_teste)
mat = confusion_matrix(y_teste, pred_lr)
print("Matriz de confusão: \n"+str(mat))
# verdadeiro/verdadeiro | falso/verdadeiro
# verdadeiro/false      | falso/falso

#acurácia:
acuracia = modelo.score(x_teste,y_teste)
print("\nAcurácia: "+str(acuracia*100)+"%")
# Out:
# Matriz de confusão:
# [[13  0  0]
#  [ 0 43 15]
#  [ 0  4 75]]
#
# Acurácia: 87.33333333333333%

# %% [markdown]
# # KNN na classificação Manual

# %%
from pandas import read_csv
from sklearn import model_selection
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix

# Carregar os dados:
array = df_humans.values

# Separar array em componentes de input e output:
x = array[:,1:5]
y = array[:,0]

# Definir tamanho das amostras:
teste_size = 0.3

# Garantir que os resultados podem ser reproduzidos no estado randômico:
seed = 7

# Criando os conjuntos de dados de treino e de teste
x_treino, x_teste, y_treino, y_teste = model_selection.train_test_split(x, y, test_size = teste_size, random_state = seed)

# Criação do modelo
modelo = KNeighborsClassifier()
modelo.fit(x_treino, y_treino)

# matriz de confusão:
pred_knn = modelo.predict(x_teste)
mat = confusion_matrix(y_teste, pred_knn)
print("Matriz de confusão: \n"+str(mat))

#acurácia:
acuracia = modelo.score(x_teste,y_teste)
print("\nAcurácia: "+str(acuracia*100)+"%")
# Out:
# Matriz de confusão:
# [[ 8  5  0]
#  [ 3 47  8]
#  [ 0 16 63]]
#
# Acurácia: 78.66666666666666%

# %% [markdown]
# # SVM na classificação Manual

# %%
from pandas import read_csv
from sklearn import model_selection
from sklearn.svm import SVC
from sklearn.metrics import confusion_matrix

# Carregar os dados:
array = df_humans.values

# Separar array em componentes de input e output:
x = array[:,1:5]
y = array[:,0]

# Definir tamanho das amostras:
teste_size = 0.3

# Garantir que os resultados podem ser reproduzidos no estado randômico:
seed = 7

# Criando os conjuntos de dados de treino e de teste
x_treino, x_teste, y_treino, y_teste = model_selection.train_test_split(x, y, test_size = teste_size, random_state = seed)

# Criação do modelo
modelo = SVC()
modelo.fit(x_treino, y_treino)

# matriz de confusão:
pred = modelo.predict(x_teste)
mat = confusion_matrix(y_teste,pred)
print("Matriz de confusão: \n"+str(mat))

#acurácia:
acuracia = modelo.score(x_teste,y_teste)
print("\nAcurácia: "+str(acuracia*100)+"%")
# Out:
# Matriz de confusão:
# [[ 0  0 13]
#  [ 0  1 57]
#  [ 0  0 79]]
#
# Acurácia: 53.333333333333336%

# %% [markdown]
# # Naive Bayes na classificação Manual

# %%
from pandas import read_csv
from sklearn import model_selection
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import confusion_matrix

# Carregar os dados:
array = df_humans.values

# Separar array em componentes de input e output:
x = array[:,1:5]
y = array[:,0]

# Definir tamanho das amostras:
teste_size = 0.3

# Garantir que os resultados podem ser reproduzidos no estado randômico:
seed = 7

# Criando os conjuntos de dados de treino e de teste
x_treino, x_teste, y_treino, y_teste = model_selection.train_test_split(x, y, test_size = teste_size, random_state = seed)

# Criação do modelo
modelo = GaussianNB()
modelo.fit(x_treino, y_treino)

# matriz de confusão:
pred_nb = modelo.predict(x_teste)
mat = confusion_matrix(y_teste, pred_nb)
print("Matriz de confusão: \n"+str(mat))

#acurácia:
acuracia = modelo.score(x_teste,y_teste)
print("\nAcurácia: "+str(acuracia*100)+"%")
# Out:
# Matriz de confusão:
# [[13  0  0]
#  [ 0 52  6]
#  [ 0  2 77]]
#
# Acurácia: 94.66666666666667%

# %% [markdown]
# # Random Forest na classificação manual

# %%
from pandas import read_csv
from sklearn import model_selection
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix

# Carregar os dados:
array = df_humans.values

# Separar array em componentes de input e output:
x = array[:,1:5]
y = array[:,0]

# Definir tamanho das amostras:
teste_size = 0.3

# Garantir que os resultados podem ser reproduzidos no estado randômico:
seed = 7

# Criando os conjuntos de dados de treino e de teste
x_treino, x_teste, y_treino, y_teste = model_selection.train_test_split(x, y, test_size = teste_size, random_state = seed)

# Criação do modelo
num_arvores = 15
max_features = 3
modelo = RandomForestClassifier(n_estimators=num_arvores,max_features=max_features)
modelo.fit(x_treino, y_treino)

# # matriz de confusão:
pred_rf = modelo.predict(x_teste)
mat = confusion_matrix(y_teste, pred_rf)
print("Matriz de confusão: \n"+str(mat))

# #acurácia:
acuracia = modelo.score(x_teste,y_teste)
print("\nAcurácia: "+str(acuracia*100)+"%")
# Out:
# Matriz de confusão:
# [[13  0  0]
#  [ 0 54  4]
#  [ 0  0 79]]
#
# Acurácia: 97.33333333333334%

# %% [markdown]
# ### ESCOLHIDO O ALGORITMO DE CLASSIFICAÇ˜AO POR ARVORE
#
# Assim, realiza novamente o load do modelo com os dados originais, 500 primeiros e depois de criado o modelo
# Realizamos, a predição dos outros clientes da lista de dados
# A predição determina para qual classe de cliente cada cliente pertence: A, B ou C

# %%
df = pd.read_csv("clientes.csv", delimiter=";");df.head(10)
df = df.drop('cliente', 1)

# %%
df_humans = df[:500]
df_not_humans = df[500:]

# %%
from pandas import read_csv
from sklearn import model_selection
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix

# Carregar os dados:
array = df_humans.values

# Separar array em componentes de input e output:
x = array[:,1:5]
y = array[:,0]

# Definir tamanho das amostras:
teste_size = 0.3

# Garantir que os resultados podem ser reproduzidos no estado randômico:
seed = 7

# Criando os conjuntos de dados de treino e de teste
x_treino, x_teste, y_treino, y_teste = model_selection.train_test_split(x, y, test_size = teste_size, random_state = seed)

# Criação do modelo
modelo = DecisionTreeClassifier()
modelo.fit(x_treino, y_treino)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
# Remove a coluna do Perfil
array_nh = df_not_humans.values

# A lista a ser predita eh dos dados sem classificacao
x_pred = array_nh[:,1:5]

# %%
#Predição do restanto dos dados
pred_new = modelo.predict(x_pred)
new_pd = pd.DataFrame()

# %%
df_not_humans['perfil'] = pred_new
# Out:
# /Users/simas/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df_not_humans.head(10)
# Out:
#     perfil  valor_total_ticket  idade  renda_sm  recorrencia
# 500      c                7240     33       7.5           63
# 501      c                7631     36       7.5           45
# 502      c                6917     32       4.5           60
# 503      b                5560     25       5.4           47
# 504      b                6362     33       3.3           30
# 505      c                6826     30       4.8           69
# 506      b                5579     28       4.5           40
# 507      b                5473     22       3.3           42
# 508      b                5675     26       3.9           51
# 509      b                6509     28       4.5           40

# %%
df_not_humans['ticket_medio'] = df_not_humans['valor_total_ticket'] / df_not_humans['recorrencia']
# Out:
# /Users/simas/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# #### Análise exploratória dos dados - estatística descritiva

# %%
# Shape é o formarto do arquivo. Quantidade de linhas e colunas.
df_not_humans.shape
# Out:
# (128254, 6)

# %%
# Apresenta todos os atributos e os tipos de entradas
df_not_humans.dtypes
# Out:
# perfil                 object
# valor_total_ticket      int64
# idade                   int64
# renda_sm              float64
# recorrencia             int64
# ticket_medio          float64
# dtype: object

# %%
# Apresenta uma prévia calculada das colunas
df_not_humans.describe()
# Out:
#        valor_total_ticket          idade       renda_sm    recorrencia  \
# count       128254.000000  128254.000000  128254.000000  128254.000000
# mean          6234.051195      29.565144       4.722784      46.667426
# std            843.503975       4.951132       1.708244      14.316795
# min           4301.000000      20.000000       0.300000      10.000000
# 25%           5663.000000      26.000000       3.900000      40.000000
# 50%           6216.000000      30.000000       4.800000      49.000000
# 75%           6856.000000      33.000000       6.000000      57.000000
# max           7999.000000      44.000000       7.500000      69.000000
#
#         ticket_medio
# count  128254.000000
# mean      155.176388
# std        81.600305
# min        71.028986
# 25%       113.159091
# 50%       131.186047
# 75%       155.847902
# max       589.900000

# %%
# Apresentação gráfica dos valores dos atributos
df_not_humans.plot()

# %%
# Identificar o melhor co-relacionamento. Aqui é identificado a "ociosidade -> Outcome"
df_not_humans.corr()
# Out:
#                     valor_total_ticket     idade  renda_sm  recorrencia
# valor_total_ticket            1.000000 -0.096250  0.483552     0.516022
# idade                        -0.096250  1.000000 -0.162609    -0.168337
# renda_sm                      0.483552 -0.162609  1.000000     0.771721
# recorrencia                   0.516022 -0.168337  0.771721     1.000000

# %%
# Saber se a distribuição é normal ou não:
# zero é simétrica
# positivo indica uma assimetria positiva 
# negativo indica uma assimetria negativa
df.skew()
# Out:
# valor_total_ticket    0.023663
# idade                 0.229640
# renda_sm             -0.627079
# recorrencia          -0.877192
# dtype: float64

# %% [markdown]
# #### Análise exploratória dos dados - visualizando seus dados

# %%
# Identificação se os dados estão mais normalizados
df_not_humans.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x109e618d0>,
# ...
#       dtype=object)

# %%
df_not_humans.plot(kind = "density", subplots = True, layout = (4,3))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1a1e62c080>,
# ...
#       dtype=object)

# %%
import seaborn as sns

# %%
# Obter as junções que estão de forma crescente na diagonal
sns.pairplot(df_not_humans)

# %%
sns.boxplot(data = df_not_humans, orient ="h")

# %%
# valor_total_ticket	idade	renda_sm	recorrencia
df_idade = df_not_humans.drop('valor_total_ticket', 1)
df_idade = df_idade.drop('renda_sm', 1)
df_idade = df_idade.drop('recorrencia', 1)
df_idade = df_idade.drop('ticket_medio', 1)
sns.boxplot(data = df_idade, orient ="h")

# %%
df_renda = df_not_humans.drop('valor_total_ticket', 1)
df_renda = df_renda.drop('idade', 1)
df_renda = df_renda.drop('recorrencia', 1)
df_renda = df_renda.drop('ticket_medio', 1)
sns.boxplot(data = df_renda, orient ="h")

# %%
df_ticket_medio = df_not_humans.drop('valor_total_ticket', 1)
df_ticket_medio = df_ticket_medio.drop('renda_sm', 1)
df_ticket_medio = df_ticket_medio.drop('recorrencia', 1)
df_ticket_medio = df_ticket_medio.drop('idade', 1)
sns.boxplot(data = df_ticket_medio, orient ="h")

# %%
df_total_ticket = df_not_humans.drop('ticket_medio', 1)
df_total_ticket = df_total_ticket.drop('renda_sm', 1)
df_total_ticket = df_total_ticket.drop('recorrencia', 1)
df_total_ticket = df_total_ticket.drop('idade', 1)
sns.boxplot(data = df_total_ticket, orient ="h")

# %%
from scipy import stats
sns.distplot(df_not_humans.renda_sm, fit = stats.norm);
# Out:
# /Users/simas/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %% [markdown]
# ## Redução da dimensionalidade

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=4)
df_pca = pca.fit_transform(x) # são os atributos

# %%
pca.explained_variance_ratio_
# Out:
# array([9.99754967e-01, 2.11351302e-04, 3.21977848e-05, 1.48401898e-06])

# %%
df_pca
# Out:
# array([[ 2.89511664e+02, -6.11560582e+00, -4.69161543e+00,
#         -1.02561853e+00],
#        [-1.43444493e+03,  7.38075507e+00,  3.94319273e+00,
#          2.12162682e+00],
#        [ 4.32550892e+02, -2.32543292e+00, -4.87724059e+00,
#         -1.46054387e+00],
#        ...,
#        [-9.27587319e+02, -1.11275767e+01,  3.23856672e+00,
#          9.79036228e-01],
#        [ 5.80428821e+02, -1.69129388e+01, -5.94504959e+00,
#          1.11931774e-01],
#        [-8.44330435e+01,  2.47387977e+00,  1.67116608e+00,
#          5.65565974e-01]])

# %% [markdown]
# ## Valor total por Ticket X Classe

# %%
df_class_a = df_not_humans.query('perfil=="a"')
df_class_b = df_not_humans.query('perfil=="b"')
df_class_c = df_not_humans.query('perfil=="c"')

# %%
df_class_a = df_class_a.drop('perfil', 1)
df_class_b = df_class_b.drop('perfil', 1)
df_class_c = df_class_c.drop('perfil', 1)

# %%
df_class_a.describe()
# Out:
#        valor_total_ticket         idade      renda_sm   recorrencia
# count        12912.000000  12912.000000  12912.000000  12912.000000
# mean          5062.934944     35.255189      1.049744     14.109511
# std            453.789634      5.330791      0.512435      2.766675
# min           4301.000000     23.000000      0.300000     10.000000
# 25%           4677.000000     32.000000      0.600000     12.000000
# 50%           5048.000000     36.000000      0.900000     14.000000
# 75%           5425.000000     40.000000      1.500000     16.000000
# max           5899.000000     44.000000      1.800000     19.000000

# %%
df_class_b.describe()
# Out:
#        valor_total_ticket         idade      renda_sm   recorrencia
# count        48441.000000  48441.000000  48441.000000  48441.000000
# mean          6054.238558     27.329225      4.177457     41.590884
# std            654.103487      4.196469      0.775248      5.826135
# min           4901.000000     20.000000      3.000000     30.000000
# 25%           5542.000000     24.000000      3.600000     37.000000
# 50%           6065.000000     27.000000      4.200000     42.000000
# 75%           6598.000000     31.000000      4.800000     46.000000
# max           7998.000000     38.000000      5.700000     51.000000

# %%
df_class_c.describe()
# Out:
#        valor_total_ticket         idade      renda_sm   recorrencia
# count        66901.000000  66901.000000  66901.000000  66901.000000
# mean          6590.275422     30.085918      5.826541     56.626926
# std            774.243503      4.315045      1.034843      6.667046
# min           4901.000000     20.000000      4.200000     45.000000
# 25%           6002.000000     27.000000      4.800000     51.000000
# 50%           6524.000000     30.000000      5.700000     56.000000
# 75%           7242.000000     33.000000      6.600000     61.000000
# max           7999.000000     38.000000      7.500000     69.000000

# %% [markdown]
# Salvando dados reunidos no novo arquivo clientes_classificados.csv

# %%
df_not_humans.to_csv('clientes_classificados.csv', sep=',')

# %%
from pandas import read_csv
from sklearn import model_selection
from sklearn.cluster import KMeans

# Carregar os dados:
array = df_humans.values

# Separar array em componentes de input e output:
x = array[:,1:5]
y = array[:,0]

# Criação do modelo
modelo = KMeans(n_clusters = 3)
modelo.fit(x)

import matplotlib.pyplot as plt
# %matplotlib inline
plt.scatter(x[:, 0], x[:,1], s = 100, c = modelo.labels_)
